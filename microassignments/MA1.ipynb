# %% [markdown]
# # CptS 215 Data Analytics Systems and Algorithms
# [Washington State University](https://wsu.edu)
#
# Original Author - [Gina Sprint](http://eecs.wsu.edu/~gsprint/)
#
# Updated by:
#  [Kyle Doty](http://eecs.wsu.edu/~kdoty/),  [Srini Badri](https://school.eecs.wsu.edu/people/faculty/)
# ## MA1 Introduction (50 pts)
# <mark>Due: </mark>
#
# ### Learner Objectives
# At the conclusion of this micro assignment, participants should be able to:
# * Post to Blackboard Class Discussions
# * Execute basic OS commands
# * Write a Python program that makes use of conditionals and loops
#
# ### Prerequisites
# Before starting this micro assignment, participants should be able to:
# * Log in to Blackboard

# %% [markdown]
# ## Overview and Requirements
# For this micro assignment you are going to introduce yourself via a Blackboard post, use the command line to setup a directory hierarchy for this class, and write a basic Python program.
#
# ### Blackboard Post (10 pts)
# 1. Log in to Blackboard and click on Class Discussions. Next click on "MA1" forum link:
# <img src="http://eecs.wsu.edu/~kdoty/CptS_215/MA1/discussion_board_location.png" width="900">
# <br>In the upper left corner, click the "Create Thread" button
# <img src="http://eecs.wsu.edu/~kdoty/CptS_215/MA1/blackboard_post_button.png" width="900">
# You should see a page that looks like the following:
# <img src="http://eecs.wsu.edu/~kdoty/CptS_215/MA1/blackboard_blank_post.png" width="900">
# 1. Now, make a post in Blackboard with your name as subject. Your post should contain the following information about yourself:
#     1. (1 pt) Your name
#     1. (1 pt) Your major
#     1. (1 pt) Where you currently live
#     1. (2 pts) Why are you taking CptS 215
#     1. (2 pts) What do you want to do with data analytics?
#     1. (3 pts) A picture of something fun you did from the most recent break (e.g. summer break or winter break) (using the "Insert/Edit Image" button)
#
# <img src="http://eecs.wsu.edu/~kdoty/CptS_215/MA1/blackboard_insert_image.png" width="600">
# Take a screenshot of your Blackboard post and save it into an image file (e.g. .png, .jpg, etc.) called `blackboard_post.png`.
#
# ### Command Line (20 pts)
# Using the OS commands learned in [L1-2](https://nbviewer.jupyter.org/github/srinibadri/cpts215/blob/fall2019/lessons/L1-2.ipynb), you are going to create a folder hierarchy suitable for this class. Perform the following:
# 1. Open the command prompt
# 1. Navigate to a folder where you would like to store files for this class (e.g. Documents, Desktop, etc.)
# 1. Create a folder called `cpts215`
# 1. Navigate into `cpts215`
# 1. Create the following folders:
#     1. `lesson_notes`
#     1. `prog_assignments`
#     1. `micro_assignments`
#     1. `project`
# 1. Navigate into `micro_assignments`
# 1. Create a directory called `MA1`
# 1. Navigate into `MA1`
# 1. Create a new .py file called `primality_test.py`
# 1. Navigate back to `cpts215`
# 1. Get a long listing of the files in `cpts215`
# 1. Get a tree listing of the files in `cpts215`
#
# Save the commands you entered to perform the above steps (and the commands' output) into a text file called `ma1_folder_commands.txt`.
#
# ### Python Program (20 pts)
# Write a program (`primality_test.py`) that prompts the user for an integer, `n`, where `n` is greater than or equal to 2. Define a predicate function, `is_prime(n)`, that accepts an integer argument `n` and returns `True` if `n` is prime, `False` otherwise.
#
# A natural number (i.e. 1, 2, 3, 4, 5, 6, etc.) is called a prime number (or a prime) if it has exactly two positive divisors, 1 and the number itself. Natural numbers greater than 1 that are not prime are called composite.
#
# To test if a number is prime or not, implement the trial division approach below (adapted from [Wikipedia](https://en.wikipedia.org/wiki/Primality_test)):
#
# >Given an input number `n`, check whether any prime integer `m` from 2 to $\sqrt{n}$ evenly divides `n` (the division leaves no remainder). If `n` is divisible by any `m` then `n` is composite, otherwise it is prime.
#
# >For example, we can do a trial division to test the primality of 100. Let's look at all the divisors of 100:
#
# >2, 4, 5, 10, 20, 25, 50
#
# >Here we see that the largest factor is 100/2 = 50. This is true for all `n`: all divisors are less than or equal to `n / 2`.
#
# >Note: If we take a closer look at the divisors, we will see that some of them are redundant. If we write the list differently:
#
# >100 = 2 × 50 = 4 × 25 = 5 × 20 = 10 × 10 = 20 × 5 = 25 × 4 = 50 × 2
#
# >the redundancy becomes obvious. Once we reach 10, which is $\sqrt{100}$, the divisors just flip around and repeat. Therefore, we can further eliminate testing divisors greater than $\sqrt{n}$.
#
# Use functions where appropriate!
#
# Example outputs:
#
# ```
# Please enter an integer >= 2: 100
# 100 is not prime!
#
# Please enter an integer >= 2: 17
# 17 is prime!
#
# Please enter an integer >= 2: 97
# 97 is prime!
# ```
#
# ## Bonus (2 pts)
# Extend your previous program to prompt the user for an integer, `M`. Sum all of the prime numbers from 2 to `M`. In your solution, include a function called `sum_primes()` that accepts an integer `M` as an argument and returns the sum of all primes from 2 to `M`.

# %% [markdown]
# ## Submitting Assignments
# 1.	Use the Blackboard tool https://learn.wsu.edu to submit your assignment. You will submit your code to the corresponding programming assignment under the "Content" tab. You must upload your solutions as `<your last name>_ma1.zip` by the due date and time.
# 2.	Your .zip file should contain your image file (e.g. `blackboard_post.png`), .txt file (`ma1_folder_commands.txt`), and .py file (`primality_test.py`).

# %% [markdown]
# ## Grading Guidelines
# This assignment is worth 50 points + 2 points bonus. Your assignment will be evaluated based on a successful compilation and adherence to the program requirements. We will grade according to the following criteria:
# * 10 pts for posting to Blackboard
# * 20 pts for executing commands at the command line to build the specified folder hierarchy
# * 18 pts for writing a program to test for primality
# * 2 pts for adherence to proper programming style and comments established for the class
